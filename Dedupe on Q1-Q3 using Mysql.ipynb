# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import mysql.connector

# %%
#pip install mysql-connector-python

# %%
#Establishing a connection with the database
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="******"
    
)

print(mydb)

# %%
Dedupe_tables =  pd.read_sql_query('SHOW TABLES FROM Dedupe', mydb)

# %%
Dedupe_tables
# Out:
#       Tables_in_dedupe
# 0  combinedsamplesq1q3

# %%
df = pd.read_sql_query('SELECT * FROM Dedupe.combinedsamplesq1q3', mydb)

# %%
df
# Out:
#        BUSINESS_UNIT PSC_CODE               OBJ_CODE         SUB_OBJ_DESCR  \
# 0              ADDIS     V212    TRANSPORT OF THINGS   HHE PACKAGE&CRATING
# 1              NEWDE     S206    GRANTS/CONT/SUBSIDY     VALUE-ADDED TAXES
# 2              SKOPJ     7510    GRANTS/CONT/SUBSIDY  VALUE ADDED TAXES (V
# 3              KAMPA     D322    TRANSPORT OF THINGS   TRANSPORT GOVT PROP
# 4              DILI_     Z1ND  RENTS, COMM&UTILITIES                SEWAGE
# ...              ...      ...                    ...                   ...
# 567190         NEWDE     9540   SUPPLIES & MATERIALS  SECURITY SUPPLIES, M
# 567191         THEHA     6515   SUPPLIES & MATERIALS      MEDICAL SUPPLIES
# 567192         RIYAD     8135    TRANSPORT OF THINGS   HHE PACKAGE&CRATING
# 567193         DSATA     R408         OTHER SERVICES  CONTRACTADVIS AND AS
# 567194         DUBAI     5130   SUPPLIES & MATERIALS  BLDG REPR SUPPL/MAIL
#
#                                      ORDER_DATE  \
# ...

# %%
df.shape
# Out:
# (567195, 13)

# %%
import pandas_dedupe

# %%
#To perform active machine learning
df = pandas_dedupe.dedupe_dataframe(df,['clean_title_desc'])
# Out:
# Importing data ...
# Reading from dedupe_dataframe_learned_settings
# Clustering...
# # duplicate sets 86221

# %%
df
# Out:
#        BUSINESS_UNIT PSC_CODE              OBJ_CODE         SUB_OBJ_DESCR  \
# 0              addis     v212   transport of things    hhe packagecrating
# 1              newde     s206   grants/cont/subsidy     value-added taxes
# 2              skopj     7510   grants/cont/subsidy  value added taxes (v
# 3              kampa     d322   transport of things   transport govt prop
# 4              dili_     z1nd  rents, commutilities                sewage
# ...              ...      ...                   ...                   ...
# 567190         newde     9540    supplies materials  security supplies, m
# 567191         theha     6515    supplies materials      medical supplies
# 567192         riyad     8135   transport of things    hhe packagecrating
# 567193         dsata     r408        other services  contractadvis and as
# 567194         dubai     5130    supplies materials  bldg repr suppl/mail
#
#                                      ORDER_DATE  \
# ...

# %%
#Convert dataframe to csv format
df.to_csv(r'combinedq1-q3dedupe.csv', index = False)
